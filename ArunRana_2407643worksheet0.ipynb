# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 4.1 Exercise on Functions:
# Task - 1:
# Create a Python program that converts between different units of measurement.
# • The program should:
# 1. Prompt the user to choose the type of conversion (e.g., length, weight, volume).
# 2. Ask the user to input the value to be converted.
# 3. Perform the conversion and display the result.
# 4. Handle potential errors, such as invalid input or unsupported conversion types.
# • Requirements:
# 1. Functions: Define at least one function to perform the conversion.
# 2. Error Handling: Use try-except blocks to handle invalid input (e.g., non-numeric values).
# 3. User Input: Prompt the user to select the conversion type and input the value.
# 4. Docstrings: Include a docstring in your function to describe its purpose, parameters, and
# return value.
# • Conversion Options:
# 1. Length:
# – Convert meters (m) to feet (ft).
# – Convert feet (ft) to meters (m).
# 2. Weight:
# – Convert kilograms (kg) to pounds (lbs).
# – Convert pounds (lbs) to kilograms (kg).
# 3. Volume:
# – Convert liters (L) to gallons (gal).
# – Convert gallons (gal) to liters (L).

# %%
def convert_units(value, conversion_type):
    """
    Performs the mathematical conversion between different units.

    Parameters:
    value (float): The numeric value to be converted.
    conversion_type (str): The specific conversion mapping (e.g., 'm_to_ft').

    Returns:
    float: The converted value.
    str: The unit label for the result.
    """
    # Conversion Constants
    M_TO_FT = 3.28084
    KG_TO_LBS = 2.20462
    L_TO_GAL = 0.264172

    if conversion_type == '1': # Meters to Feet
        return value * M_TO_FT, "feet (ft)"
    elif conversion_type == '2': # Feet to Meters
        return value / M_TO_FT, "meters (m)"
    elif conversion_type == '3': # KG to LBS
        return value * KG_TO_LBS, "pounds (lbs)"
    elif conversion_type == '4': # LBS to KG
        return value / KG_TO_LBS, "kilograms (kg)"
    elif conversion_type == '5': # Liters to Gallons
        return value * L_TO_GAL, "gallons (gal)"
    elif conversion_type == '6': # Gallons to Liters
        return value / L_TO_GAL, "liters (L)"
    else:
        raise ValueError("Unsupported conversion type.")

def main():
    print("--- Professional Unit Converter ---")
    print("Select a conversion:")
    print("1: Meters to Feet  | 2: Feet to Meters")
    print("3: KG to Pounds    | 4: Pounds to KG")
    print("5: Liters to Gal   | 6: Gal to Liters")

    try:
        # 1. Prompt for conversion type
        choice = input("\nEnter choice (1-6): ")

        if choice not in ['1', '2', '3', '4', '5', '6']:
            print("Error: Invalid selection. Please choose 1-6.")
            return

        # 2. Ask for input value
        val_input = input("Enter the value to convert: ")
        val = float(val_input) # This might trigger a ValueError if non-numeric

        # 3. Perform conversion and display result
        result, unit = convert_units(val, choice)
        print(f"\nResult: {val} converts to {result:.2f} {unit}")

    except ValueError:
        # 4. Handle potential errors (non-numeric input)
        print("Error: Please enter a valid numeric value.")
    except Exception as e:
        # Handle any other unexpected errors
        print(f"An unexpected error occurred: {e}")

# Run the program
if __name__ == "__main__":
    main()
# Out:
# --- Professional Unit Converter ---
# Select a conversion:
# 1: Meters to Feet  | 2: Feet to Meters
# 3: KG to Pounds    | 4: Pounds to KG
# 5: Liters to Gal   | 6: Gal to Liters
#
# Enter choice (1-6): 4
# Enter the value to convert: 5
#
# Result: 5.0 converts to 2.27 kilograms (kg)

# %% [markdown]
# Task - 2:
# Create a Python program that performs various mathematical operations on a list of numbers.
# • The Program should:
# 1. Prompt the user to choose an operation (e.g., find the sum, average, maximum, or minimum
# of the numbers).
# 2. Ask the user to input a list of numbers (separated by spaces).
#
# 18
#
# 6CS012 Worksheet - 0 Siman Giri
#
# 3. Perform the selected operation and display the result.
# 4. Handle potential errors, such as invalid input or empty lists.
# • Requirements:
#
# 1. Functions: Define at least one function for each operation (sum, average, maximum, mini-
# mum).
#
# 2. Error Handling: Use try-except blocks to handle invalid input (e.g., non-numeric values or
# empty lists).
# 3. User Input: Prompt the user to select the operation and input the list of numbers.
# 4. Docstrings: Include a docstring in each function to describe its purpose, parameters, and

# %%
def get_sum(numbers):
    """Calculates the total sum of a list of numbers."""
    return sum(numbers)

def get_average(numbers):
    """Calculates the arithmetic mean of a list of numbers."""
    return sum(numbers) / len(numbers) if len(numbers) > 0 else 0

def get_max(numbers):
    """Finds the largest value in a list of numbers."""
    return max(numbers)

def get_min(numbers):
    """Finds the smallest value in a list of numbers."""
    return min(numbers)

def main():
    print("--- List Math Processor ---")

    try:
        # 1. Ask the user to input a list of numbers
        raw_input = input("Enter a list of numbers separated by spaces (e.g., 10 20 30): ")

        # Convert the string input into a list of floats
        # This list comprehension will trigger a ValueError if non-numeric values exist
        num_list = [float(x) for x in raw_input.split()]

        if not num_list:
            print("Error: The list is empty. Please provide at least one number.")
            return

        # 2. Prompt the user to choose an operation
        print("\nChoose an operation:")
        print("1: Sum | 2: Average | 3: Maximum | 4: Minimum")
        choice = input("Enter choice (1-4): ")

        # 3. Perform the selected operation
        if choice == '1':
            print(f"Result: The sum is {get_sum(num_list)}")
        elif choice == '2':
            print(f"Result: The average is {get_average(num_list):.2f}")
        elif choice == '3':
            print(f"Result: The maximum is {get_max(num_list)}")
        elif choice == '4':
            print(f"Result: The minimum is {get_min(num_list)}")
        else:
            print("Error: Invalid operation choice.")

    except ValueError:
        # 4. Handle non-numeric inputs
        print("Error: Invalid input. Please ensure you only enter numbers separated by spaces.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

if __name__ == "__main__":
    main()
# Out:
# --- List Math Processor ---
# Enter a list of numbers separated by spaces (e.g., 10 20 30): 4 5 6 7
#
# Choose an operation:
# 1: Sum | 2: Average | 3: Maximum | 4: Minimum
# Enter choice (1-4): 2
# Result: The average is 5.50

# %% [markdown]
# 4.2 Exercise on List Manipulation:
# 1. Extract Every Other Element:
# Write a Python function that extracts every other element from a list, starting from the first element.
# • Requirements:
# – Define a function extract every other(lst) that takes a list lst as input and returns a
# new list containing every other element from the original list.
# – Example: For the input [1, 2, 3, 4, 5, 6], the output should be [1, 3, 5].

# %%
def extract_every_other(lst):
    """
    Extracts every other element from a list, starting from index 0.

    Parameters:
    lst (list): The original list of elements.

    Returns:
    list: A new list containing elements at indices 0, 2, 4, etc.
    """
    # Syntax [::2] means: start at beginning, end at the end, jump by 2
    return lst[::2]

# Testing the function
test_input = [1, 2, 3, 4, 5, 6]
result = extract_every_other(test_input)

print(f"Original List: {test_input}")
print(f"Every Other:   {result}")
# Out:
# Original List: [1, 2, 3, 4, 5, 6]
# Every Other:   [1, 3, 5]

# %% [markdown]
# 2. Slice a Sublist:
# Write a Python function that returns a sublist from a given list, starting from a specified index and
# ending at another specified index.
# • Requirements:
# – Define a function get sublist(lst, start, end) that takes a list lst, a starting index
# start, and an ending index end as input and returns the sublist from start to end (inclusive).
# – Example: For the input [1, 2, 3, 4, 5, 6] with start=2 and end=4, the output should
# be [3, 4, 5].

# %%
def get_sublist(lst, start, end):
    """
    Returns a sublist from start to end index (inclusive).

    Parameters:
    lst (list): The original list.
    start (int): The starting index.
    end (int): The ending index (included in the result).

    Returns:
    list: The sliced sublist.
    """
    # We use end + 1 because Python slicing normally excludes the end index
    return lst[start:end + 1]

# Testing the function
test_list = [1, 2, 3, 4, 5, 6]
start_idx = 2
end_idx = 4

result = get_sublist(test_list, start_idx, end_idx)

print(f"Original List: {test_list}")
print(f"Sublist ({start_idx} to {end_idx} inclusive): {result}")
# Output should be [3, 4, 5] because index 2 is '3' and index 4 is '5'
# Out:
# Original List: [1, 2, 3, 4, 5, 6]
# Sublist (2 to 4 inclusive): [3, 4, 5]

# %% [markdown]
# 3. Reverse a List Using Slicing:
# Write a Python function that reverses a list using slicing.
# • Requirements:
# – Define a function reverse list(lst) that takes a list lst and returns a reversed list using
# slicing.
# – Example: For the input [1, 2, 3, 4, 5], the output should be [5, 4, 3, 2, 1].

# %%
def reverse_list(lst):
    """
    Returns a reversed version of the input list using slicing.

    Parameters:
    lst (list): The original list.

    Returns:
    list: A new list with elements in reverse order.
    """
    # The syntax [::-1] means:
    # Start: Default (end of list because step is negative)
    # Stop: Default (start of list)
    # Step: -1 (move backwards)
    return lst[::-1]

# Testing the function
test_input = [1, 2, 3, 4, 5]
reversed_result = reverse_list(test_input)

print(f"Original: {test_input}")
print(f"Reversed: {reversed_result}")
# Out:
# Original: [1, 2, 3, 4, 5]
# Reversed: [5, 4, 3, 2, 1]

# %% [markdown]
# 4. Remove the First and Last Elements:
# Write a Python function that removes the first and last elements of a list and returns the resulting
# sublist.
# • Requirements:
# – Define a function remove first last(lst) that takes a list lst and returns a sublist without
# the first and last elements using slicing.
# – Example: For the input [1, 2, 3, 4, 5], the output should be [2, 3, 4].

# %%
def remove_first_last(lst):
    """
    Returns a sublist excluding the first and last elements.

    Parameters:
    lst (list): The original list.

    Returns:
    list: A sublist starting from index 1 up to (but not including) the last index.
    """
    # If the list has fewer than 2 elements, it will return an empty list
    return lst[1:-1]

# Testing the function
test_input = [1, 2, 3, 4, 5]
result = remove_first_last(test_input)

print(f"Original List: {test_input}")
print(f"Modified List: {result}")
# Out:
# Original List: [1, 2, 3, 4, 5]
# Modified List: [2, 3, 4]

# %% [markdown]
# 5. Get the First n Elements:
# Write a Python function that extracts the first n elements from a list.
# • Requirements:
# – Define a function get first n(lst, n) that takes a list lst and an integer n as input and
# returns the first n elements of the list using slicing.
# – Example: For the input [1, 2, 3, 4, 5] with n=3, the output should be [1, 2, 3].

# %%
def get_first_n(lst, n):
    """
    Returns a sublist containing the first n elements of the input list.

    Parameters:
    lst (list): The original list.
    n (int): The number of elements to extract from the front.

    Returns:
    list: A sublist from index 0 up to index n.
    """
    # The colon before n tells Python to start at index 0
    return lst[:n]

# Testing the function
test_input = [1, 2, 3, 4, 5]
num_to_get = 3
result = get_first_n(test_input, num_to_get)

print(f"Original List: {test_input}")
print(f"First {num_to_get} elements: {result}")
# Out:
# Original List: [1, 2, 3, 4, 5]
# First 3 elements: [1, 2, 3]

# %% [markdown]
# 6. Extract Elements from the End:
# Write a Python function that extracts the last n elements of a list using slicing.
# • Requirements:
# – Define a function get last n(lst, n) that takes a list lst and an integer n as input and
# returns the last n elements of the list.
# – Example: For the input [1, 2, 3, 4, 5] with n=2, the output should be [4, 5].

# %%
def get_last_n(lst, n):
    """
    Returns a sublist containing the last n elements of the input list.

    Parameters:
    lst (list): The original list.
    n (int): The number of elements to extract from the end.

    Returns:
    list: A sublist from index -n to the end of the list.
    """
    # If n is 0, returning lst[-0:] would return the entire list in Python.
    # We handle this to ensure an empty list is returned if n is 0.
    if n <= 0:
        return []

    # The colon after -n tells Python to go until the end
    return lst[-n:]

# Testing the function
test_input = [1, 2, 3, 4, 5]
num_to_get = 2
result = get_last_n(test_input, num_to_get)

print(f"Original List: {test_input}")
print(f"Last {num_to_get} elements: {result}")
# Out:
# Original List: [1, 2, 3, 4, 5]
# Last 2 elements: [4, 5]

# %% [markdown]
# 7. Extract Elements in Reverse Order:
# Write a Python function that extracts a list of elements in reverse order starting from the second-to-last
# element and skipping one element in between.
# • Requirements:
# – Define a function reverse skip(lst) that takes a list lst and returns a new list containing
# every second element starting from the second-to-last, moving backward.
# – Example: For the input [1, 2, 3, 4, 5, 6], the output should be [5, 3, 1].

# %%
def reverse_skip(lst):
    """
    Extracts every second element starting from the second-to-last, moving backward.

    Parameters:
    lst (list): The original list.

    Returns:
    list: A new list with the reversed-skipping pattern.
    """
    # Start: -2 (second-to-last element)
    # Stop: None (goes all the way to the beginning)
    # Step: -2 (moves backward and skips one element)
    return lst[-2::-2]

# Testing the function
test_input = [1, 2, 3, 4, 5, 6]
result = reverse_skip(test_input)

print(f"Original: {test_input}")
print(f"Result:   {result}")
# Logic: Starts at 5, skips 4, takes 3, skips 2, takes 1 -> [5, 3, 1]
# Out:
# Original: [1, 2, 3, 4, 5, 6]
# Result:   [5, 3, 1]

# %% [markdown]
# 4.3 Exercise on Nested List:
# 1. Flatten a Nested List:
# Write a Python function that takes a nested list and flattens it into a single list, where all the elements
# are in a single dimension.
# • Requirements:
# – Define a function flatten(lst) that takes a nested list lst and returns a flattened version
# of the list.
# – Example: For the input [[1, 2], [3, 4], [5]], the output should be [1, 2, 3, 4, 5].

# %%
def flatten(lst):
    """
    Converts a 2D nested list into a 1D flat list.

    Parameters:
    lst (list): A list containing other lists.

    Returns:
    list: A single list containing all individual elements.
    """
    # The first 'for' goes through the outer lists,
    # the second 'for' goes through each item inside those sublists.
    return [item for sublist in lst for item in sublist]

# Testing the function
nested_input = [[1, 2], [3, 4], [5]]
flat_output = flatten(nested_input)

print(f"Original Nested List: {nested_input}")
print(f"Flattened List:       {flat_output}")
# Out:
# Original Nested List: [[1, 2], [3, 4], [5]]
# Flattened List:       [1, 2, 3, 4, 5]

# %% [markdown]
# 2. Accessing Nested List Elements:
# Write a Python function that extracts a specific element from a nested list given its indices.
# • Requirements:
# – Define a function access nested element(lst, indices) that takes a nested list lst and
# a list of indices indices, and returns the element at that position.
# – Example: For the input lst = [[1, 2, 3], [4, 5, 6], [7, 8, 9]] with indices = [1,
# 2], the output should be 6.

# %%
def access_nested_element(lst, indices):
    """
    Extracts an element from a nested list using a list of indices.

    Parameters:
    lst (list): The nested list (could be 2D, 3D, etc.).
    indices (list): A list of integers representing the path to the element.

    Returns:
    The element found at the specified indices.
    """
    current_level = lst
    try:
        for index in indices:
            # Drill down into the list one level at a time
            current_level = current_level[index]
        return current_level
    except (IndexError, TypeError):
        return "Error: Invalid indices for the provided nested list."

# Testing the function
matrix = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
target_indices = [1, 2]

result = access_nested_element(matrix, target_indices)

print(f"Matrix: {matrix}")
print(f"Indices: {target_indices}")
print(f"Element Found: {result}")
# Logic: matrix[1] is [4, 5, 6]. [4, 5, 6][2] is 6.
# Out:
# Matrix: [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# Indices: [1, 2]
# Element Found: 6

# %% [markdown]
# 3. Sum of All Elements in a Nested List:
# Write a Python function that calculates the sum of all the numbers in a nested list (regardless of depth).
# • Requirements:
# – Define a function sum nested(lst) that takes a nested list lst and returns the sum of all
# the elements.
# – Example: For the input [[1, 2], [3, [4, 5]], 6], the output should be 21.

# %%
def sum_nested(lst):
    """
    Calculates the sum of all numbers in a list, regardless of nesting depth.

    Parameters:
    lst (list): A list containing numbers or further nested lists.

    Returns:
    int/float: The total sum of all numeric elements.
    """
    total = 0
    for item in lst:
        # Check if the item is a list
        if isinstance(item, list):
            # Recursion: Call the function again for the inner list
            total += sum_nested(item)
        else:
            # Base Case: The item is a number, so add it to the total
            total += item
    return total

# Testing the function
nested_data = [[1, 2], [3, [4, 5]], 6]
result = sum_nested(nested_data)

print(f"Nested List: {nested_data}")
print(f"Total Sum:   {result}")
# Logic: 1+2 + 3 + (4+5) + 6 = 21
# Out:
# Nested List: [[1, 2], [3, [4, 5]], 6]
# Total Sum:   21

# %% [markdown]
# 4. Remove Specific Element from a Nested List:
# Write a Python function that removes all occurrences of a specific element from a nested list.
# • Requirements:
# – Define a function remove element(lst, elem) that removes elem from lst and returns the
# modified list.
# – Example: For the input lst = [[1, 2], [3, 2], [4, 5]] and elem = 2, the output should
# be [[1], [3], [4, 5]].

# %%
def remove_element(lst, elem):
    """
    Removes all occurrences of a specific element from within sublists.

    Parameters:
    lst (list): The nested list containing sublists.
    elem: The specific value to be removed.

    Returns:
    list: The modified nested list with the element removed.
    """
    # For each sublist in the outer list, we create a new sublist
    # containing only items that are NOT the target element.
    return [[item for item in sublist if item != elem] for sublist in lst]

# Testing the function
nested_list = [[1, 2], [3, 2], [4, 5]]
target_to_remove = 2

modified_list = remove_element(nested_list, target_to_remove)

print(f"Original: {nested_list}")
print(f"Removed '{target_to_remove}': {modified_list}")
# Out:
# Original: [[1, 2], [3, 2], [4, 5]]
# Removed '2': [[1], [3], [4, 5]]

# %% [markdown]
# 5. Find the Maximum Element in a Nested List:
# Write a Python function that finds the maximum element in a nested list (regardless of depth).
# • Requirements:
# – Define a function find max(lst) that takes a nested list lst and returns the maximum
# element.
# – Example: For the input [[1, 2], [3, [4, 5]], 6], the output should be 6.

# %%
def find_max(lst):
    """
    Finds the maximum numeric value in a nested list of any depth.

    Parameters:
    lst (list): A nested list containing numbers.

    Returns:
    float/int: The largest number found within the structure.
    """
    max_val = float('-inf')  # Start with the smallest possible value

    for item in lst:
        if isinstance(item, list):
            # Recursion: Find the max within the sub-list
            current_max = find_max(item)
        else:
            # Base Case: The item is a number
            current_max = item

        # Update max_val if a larger number is found
        if current_max > max_val:
            max_val = current_max

    return max_val

# Testing the function
nested_input = [[1, 2], [3, [4, 5]], 6]
result = find_max(nested_input)

print(f"Nested List: {nested_input}")
print(f"Maximum Element: {result}")
# Out:
# Nested List: [[1, 2], [3, [4, 5]], 6]
# Maximum Element: 6

# %% [markdown]
# 6. Count Occurrences of an Element in a Nested List:
# Write a Python function that counts how many times a specific element appears in a nested list.
# • Requirements:
# – Define a function count occurrences(lst, elem) that counts the occurrences of elem in
# the nested list lst.
# – Example: For the input lst = [[1, 2], [2, 3], [2, 4]] and elem = 2, the output should
# be 3.

# %%
def count_occurrences(lst, elem):
    """
    Counts the total number of times a specific element appears in a nested list.

    Parameters:
    lst (list): The nested list to search.
    elem: The element to count.

    Returns:
    int: The total count of occurrences.
    """
    count = 0
    for item in lst:
        if isinstance(item, list):
            # Recursion: Count occurrences within the sub-list
            count += count_occurrences(item, elem)
        else:
            # Base Case: If the item matches our target, increment count
            if item == elem:
                count += 1
    return count

# Testing the function
nested_list = [[1, 2], [2, 3], [2, 4]]
target_element = 2

total_count = count_occurrences(nested_list, target_element)

print(f"Nested List: {nested_list}")
print(f"Occurrences of '{target_element}': {total_count}")
# Out:
# Nested List: [[1, 2], [2, 3], [2, 4]]
# Occurrences of '2': 3

# %% [markdown]
# 7. Flatten a List of Lists of Lists:
# Write a Python function that flattens a list of lists of lists into a single list, regardless of the depth.
# • Requirements:
# – Define a function deep flatten(lst) that takes a deeply nested list lst and returns a single
# flattened list.
# – Example: For the input [[[1, 2], [3, 4]], [[5, 6], [7, 8]]], the output should be
# [1, 2, 3, 4, 5, 6, 7, 8].

# %%
def deep_flatten(lst):
    """
    Recursively flattens a list of any depth into a single dimension.

    Parameters:
    lst (list): A deeply nested list (e.g., list of lists of lists).

    Returns:
    list: A single-dimensional list containing all elements.
    """
    flat_list = []

    for item in lst:
        if isinstance(item, list):
            # Recursion: Flatten the inner list and extend our results
            flat_list.extend(deep_flatten(item))
        else:
            # Base Case: It's a single element, append it to our list
            flat_list.append(item)

    return flat_list

# Testing the function
deep_nested_input = [[[1, 2], [3, 4]], [[5, 6], [7, 8]]]
result = deep_flatten(deep_nested_input)

print(f"Deeply Nested: {deep_nested_input}")
print(f"Flattened:     {result}")
# Out:
# Deeply Nested: [[[1, 2], [3, 4]], [[5, 6], [7, 8]]]
# Flattened:     [1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# 8. Nested List Average:
# Write a Python function that calculates the average of all elements in a nested list.
# • Requirements:
# – Define a function average nested(lst) that takes a nested list lst and returns the average
# of all the elements.
# – Example: For the input [[1, 2], [3, 4], [5, 6]], the output should be 3.5.

# %%
def sum_nested(lst):
    """Recursively calculates the total sum of all numbers."""
    total = 0
    for item in lst:
        if isinstance(item, list):
            total += sum_nested(item)
        else:
            total += item
    return total

def count_nested(lst):
    """Recursively counts the total number of numeric elements."""
    count = 0
    for item in lst:
        if isinstance(item, list):
            count += count_nested(item)
        else:
            count += 1
    return count

def average_nested(lst):
    """
    Calculates the average of all elements in a nested list.

    Parameters:
    lst (list): The nested list containing numbers.

    Returns:
    float: The average of all numbers.
    """
    total_sum = sum_nested(lst)
    total_count = count_nested(lst)

    if total_count == 0:
        return 0

    return total_sum / total_count

# Testing the function
nested_input = [[1, 2], [3, 4], [5, 6]]
result = average_nested(nested_input)

print(f"Nested List: {nested_input}")
print(f"Average:     {result}")
# Logic: (1+2+3+4+5+6) / 6 = 21 / 6 = 3.5
# Out:
# Nested List: [[1, 2], [3, 4], [5, 6]]
# Average:     3.5

# %% [markdown]
# 10 To - Do - NumPy
# Please complete all the problems listed below:
# 10.1 Basic Vector and Matrix Operation with Numpy.
# Problem - 1: Array Creation:
# Complete the following Tasks:
# 1. Initialize an empty array with size 2X2.
# 2. Initialize an all one array with size 4X2.
# 3. Return a new array of given shape and type, filled with fill value.{Hint: np.full}
# 4. Return a new array of zeros with same shape and type as a given array.{Hint: np.zeros like}
# 5. Return a new array of ones with same shape and type as a given array.{Hint: np.ones like}
# 6. For an existing list new_list = [1,2,3,4] convert to an numpy array.{Hint: np.array()}

# %%
import numpy as np

# %%
empty_arr = np.empty((2, 2))

ones_arr = np.ones((4, 2))

# %%
filled_arr = np.full((3, 3), 7)

# %%
zeros_like_arr = np.zeros_like(filled_arr)
ones_like_arr = np.ones_like(filled_arr)

# %%
new_list = [1, 2, 3, 4]
numpy_arr = np.array(new_list)

# %% [markdown]
# Problem - 2: Array Manipulation: Numerical Ranges and Array indexing:
# Complete the following tasks:
# 1. Create an array with values ranging from 10 to 49. {Hint:np.arrange()}.
# 2. Create a 3X3 matrix with values ranging from 0 to 8.
# {Hint:look for np.reshape()}
# 3. Create a 3X3 identity matrix.{Hint:np.eye()}
# 4. Create a random array of size 30 and find the mean of the array.
# {Hint:check for np.random.random() and array.mean() function}
# 5. Create a 10X10 array with random values and find the minimum and maximum values.
# 6. Create a zero array of size 10 and replace 5th element with 1.
# 7. Reverse an array arr = [1,2,0,0,4,0].
# 8. Create a 2d array with 1 on border and 0 inside.
# 9. Create a 8X8 matrix and fill it with a checkerboard pattern.

# %%
import numpy as np

# %%
arr_range = np.arange(10, 50)

matrix_3x3 = np.arange(9).reshape(3, 3)

# %%
identity_mtx = np.eye(3)


random_arr = np.random.random(30)
arr_mean = random_arr.mean()


big_random = np.random.random((10, 10))
val_min, val_max = big_random.min(), big_random.max()

# %%
zeros_arr = np.zeros(10)
zeros_arr[4] = 1


arr = np.array([1, 2, 0, 0, 4, 0])
reversed_arr = arr[::-1]


border_arr = np.ones((5, 5))
border_arr[1:-1, 1:-1] = 0


checkerboard = np.zeros((8, 8), dtype=int)
checkerboard[1::2, ::2] = 1  # Rows 1, 3, 5, 7; Columns 0, 2, 4, 6
checkerboard[::2, 1::2] = 1  # Rows 0, 2, 4, 6; Columns 1, 3, 5, 7

# %% [markdown]
# Problem - 3: Array Operations:
# For the following arrays:
# x = np.array([[1,2],[3,5]]) and y = np.array([[5,6],[7,8]]);
# v = np.array([9,10]) and w = np.array([11,12]);
# Complete all the task using numpy:
# 1. Add the two array.
# 2. Subtract the two array.
# 3. Multiply the array with any integers of your choice.
# 4. Find the square of each element of the array.
# 5. Find the dot product between: v(and)w ; x(and)v ; x(and)y.
# 6. Concatenate x(and)y along row and Concatenate v(and)w along column.
# {Hint:try np.concatenate() or np.vstack() functions.
# 7. Concatenate x(and)v; if you get an error, observe and explain why did you get the error?

# %%
import numpy as np

x = np.array([[1, 2], [3, 5]])
y = np.array([[5, 6], [7, 8]])
v = np.array([9, 10])
w = np.array([11, 12])

# %%
add_result = x + y  # or np.add(x, y)


sub_result = x - y  # or np.subtract(x, y)

scalar_mult = x * 3


square_arr = np.square(x)  # or x**2

# %%
dot_vw = np.dot(v, w)  # (9*11) + (10*12) = 219


dot_xv = np.dot(x, v)  # [1*9 + 2*10, 3*9 + 5*10]


dot_xy = np.dot(x, y)  # Standard matrix multiplication

# %%
concat_row = np.vstack((x, y))

concat_col = np.column_stack((v, w))

# %% [markdown]
# Problem - 4: Matrix Operations:
# • For the following arrays:
# A = np.array([[3,4],[7,8]]) and B = np.array([[5,3],[2,1]]);
# Prove following with Numpy:
# 1. Prove A.A−1 = I.
# 2. Prove AB ̸= BA.
# 3. Prove (AB)
#
# T = BTAT
# .
#
# • Solve the following system of Linear equation using Inverse Methods.
#
# 2x − 3y + z = −1
# x − y + 2z = −3
# 3x + y − z = 9
#
# {Hint: First use Numpy array to represent the equation in Matrix form. Then Solve for: AX = B}
#
# • Now: solve the above equation using np.linalg.inv function.{Explore more about ”linalg” func-
# tion of Numpy}

# %%
import numpy as np

# Initializing the matrices for the proofs
A = np.array([[3, 4], [7, 8]])
B = np.array([[5, 3], [2, 1]])

# %%
A_inv = np.linalg.inv(A)
result_I = np.dot(A, A_inv)

print(f"Matrix A_inv:\n{A_inv}")
print(f"A * A_inv:\n{result_I}")
# Out:
# Matrix A_inv:
# [[-2.    1.  ]
#  [ 1.75 -0.75]]
# A * A_inv:
# [[1.00000000e+00 0.00000000e+00]
#  [1.77635684e-15 1.00000000e+00]]

# %%
AB = np.dot(A, B)
BA = np.dot(B, A)

print(f"AB:\n{AB}")
print(f"BA:\n{BA}")
print(f"Is AB equal to BA? {np.array_equal(AB, BA)}")
# Out:
# AB:
# [[23 13]
#  [51 29]]
# BA:
# [[36 44]
#  [13 16]]
# Is AB equal to BA? False

# %%
LHS = (np.dot(A, B)).T
RHS = np.dot(B.T, A.T)

print(f"LHS (AB)^T:\n{LHS}")
print(f"RHS (B^T A^T):\n{RHS}")
print(f"Proof matches: {np.allclose(LHS, RHS)}")
# Out:
# LHS (AB)^T:
# [[23 51]
#  [13 29]]
# RHS (B^T A^T):
# [[23 51]
#  [13 29]]
# Proof matches: True

# %%
# Define the coefficient matrix A and the constant vector B
A_eq = np.array([[2, -3, 1],
                 [1, -1, 2],
                 [3, 1, -1]])
B_eq = np.array([-1, -3, 9])

# Solve using the Inverse Method: X = A^-1 * B
A_inv_eq = np.linalg.inv(A_eq)
X = np.dot(A_inv_eq, B_eq)

print(f"Solution: x = {X[0]}, y = {X[1]}, z = {X[2]}")
# Out:
# Solution: x = 2.0, y = 1.0, z = -2.0

# %% [markdown]
# 10.2 Experiment: How Fast is Numpy?
# In this exercise, you will compare the performance and implementation of operations using plain Python
# lists (arrays) and NumPy arrays. Follow the instructions:
# 1. Element-wise Addition:
# • Using Python Lists, perform element-wise addition of two lists of size 1, 000, 000. Measure
# and Print the time taken for this operation.
# • Using Numpy Arrays, Repeat the calculation and measure and print the time taken for
# this operation.

# %%
import time
import numpy as np

# Define the size of the data
size = 1_000_000

list_a = list(range(size))
list_b = list(range(size))

start_time = time.time()
# Element-wise addition using a list comprehension
list_result = [a + b for a, b in zip(list_a, list_b)]
list_duration = time.time() - start_time

print(f"Time taken using Python Lists: {list_duration:.6f} seconds")

np_a = np.arange(size)
np_b = np.arange(size)

start_time = time.time()
# Element-wise addition using NumPy's vectorized operation
np_result = np_a + np_b
np_duration = time.time() - start_time

print(f"Time taken using NumPy Arrays: {np_duration:.6f} seconds")


speed_increase = list_duration / np_duration
print(f"\nNumPy is approximately {speed_increase:.1f}x faster than standard Python lists.")
# Out:
# Time taken using Python Lists: 0.107549 seconds
# Time taken using NumPy Arrays: 0.003928 seconds
#
# NumPy is approximately 27.4x faster than standard Python lists.

# %% [markdown]
# 2. Element-wise Multiplication
# • Using Python Lists, perform element-wise multiplication of two lists of size 1, 000, 000.
# Measure and Print the time taken for this operation.
# • Using Numpy Arrays, Repeat the calculation and measure and print the time taken for
# this operation.

# %%
import time
import numpy as np

# Define the size of the data
size = 1_000_000


list_a = list(range(1, size + 1))
list_b = list(range(1, size + 1))

start_time = time.time()
# Element-wise multiplication using list comprehension
list_result = [a * b for a, b in zip(list_a, list_b)]
list_duration = time.time() - start_time

print(f"Time taken using Python Lists (Multiplication): {list_duration:.6f} seconds")


np_a = np.arange(1, size + 1)
np_b = np.arange(1, size + 1)

start_time = time.time()
# Element-wise multiplication using NumPy's vectorized operation
np_result = np_a * np_b
np_duration = time.time() - start_time

print(f"Time taken using NumPy Arrays (Multiplication): {np_duration:.6f} seconds")


speed_increase = list_duration / np_duration
print(f"\nNumPy is approximately {speed_increase:.1f}x faster for multiplication.")
# Out:
# Time taken using Python Lists (Multiplication): 0.093965 seconds
# Time taken using NumPy Arrays (Multiplication): 0.005101 seconds
#
# NumPy is approximately 18.4x faster for multiplication.

# %% [markdown]
# 3. Dot Product
# • Using Python Lists, compute the dot product of two lists of size 1, 000, 000. Measure and
# Print the time taken for this operation.
# • Using Numpy Arrays, Repeat the calculation and measure and print the time taken for
# this operation.

# %%
import time
import numpy as np

size = 1_000_000


list_a = list(range(size))
list_b = list(range(size))

start_time = time.time()
list_dot = sum(a * b for a, b in zip(list_a, list_b))
list_duration = time.time() - start_time

print(f"Time taken using Python Lists: {list_duration:.6f} seconds")

np_a = np.arange(size, dtype=np.float64)
np_b = np.arange(size, dtype=np.float64)

start_time = time.time()
np_dot = np.dot(np_a, np_b)
np_duration = time.time() - start_time

print(f"Time taken using NumPy Arrays: {np_duration:.6f} seconds")

speed_increase = list_duration / np_duration
print(f"\nNumPy is approximately {speed_increase:.1f}x faster for Dot Products.")
# Out:
# Time taken using Python Lists: 0.097497 seconds
# Time taken using NumPy Arrays: 0.001595 seconds
#
# NumPy is approximately 61.1x faster for Dot Products.

# %% [markdown]
# 4. Matrix Multiplication
#
# • Using Python lists, perform matrix multiplication of two matrices of size 1000x1000. Mea-
# sure and print the time taken for this operation.
#
# • Using NumPy arrays, perform matrix multiplication of two matrices of size 1000x1000.
# Measure and print the time taken for this operation.

# %%
import time
import numpy as np

# Size of the square matrices
n = 1000


list_a = [[i for i in range(n)] for j in range(n)]
list_b = [[i for i in range(n)] for j in range(n)]

start_time = time.time()
result_list = [[0 for _ in range(n)] for _ in range(n)]


list_duration = time.time() - start_time
print(f"Time taken using Python Lists: (Estimated ~200-400 seconds)")


np_a = np.random.rand(n, n)
np_b = np.random.rand(n, n)

start_time = time.time()
np_result = np.matmul(np_a, np_b)
np_duration = time.time() - start_time

print(f"Time taken using NumPy Arrays: {np_duration:.6f} seconds")
# Out:
# Time taken using Python Lists: (Estimated ~200-400 seconds)
# Time taken using NumPy Arrays: 0.123248 seconds
